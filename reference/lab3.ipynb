# %%
# Clear Global Environment
rm(list = ls())

getwd()
setwd("/Users/Lingyi/TAD/lab/Text-as-Data-Lab-Spr2018/W3_02-08-18")
# Out:
# [1] "/Users/Lingyi/TAD/lab/Text-as-Data-Lab-Spr2018/W3_02-08-18"

# %%
# Libraries
library(quanteda)
library(quanteda.corpora)
# Out:
# quanteda version 1.0.0
# Using 3 of 4 threads for parallel computing
#
# Attaching package: ‘quanteda’
#
# The following object is masked from ‘jupyter:irkernel’:
#
#     View
#
# The following object is masked from ‘package:utils’:
#
#     View

# %%
stopwords(language = "zh", source = "misc")
# Out:
#   [1] "按"       "按照"     "俺"       "俺"       "们"       "阿"
#   [7] "别"       "别人"     "别处"     "别"       "是"       "别的"
#  [13] "别管"     "别"       "说"       "不"       "不仅"     "不但"
#  [19] "不光"     "不单"     "不只"     "不外乎"   "不如"     "不妨"
#  [25] "不尽"     "不尽"     "然"       "不得"     "不怕"     "不惟"
#  [31] "不成"     "不拘"     "不"       "料"       "不是"     "不比"
#  [37] "不然"     "不"       "特"       "不独"     "不管"     "不至于"
#  [43] "不"       "若"       "不论"     "不过"     "不问"     "比"
#  [49] "方"       "比如"     "比"       "及"       "比"       "本身"
#  [55] "本着"     "本地"     "本人"     "本"       "巴巴"     "巴"
#  [61] "并"       "并且"     "非"       "彼"       "彼"       "时"
#  [67] "彼此"     "便于"     "把"       "边"       "鄙人"     "罢了"
#  [73] "被"       "般"       "的"       "此"       "间"       "此次"
#  [79] "此时"     "此外"     "此"       "处"       "此地"     "此"
#  [85] "才"       "才能"     "朝"       "朝着"     "从"       "从此"
#  [91] "从而"     "除非"     "除此之外" "除"       "开"       "除外"
#  [97] "除了"     "除"       "诚"       "然"       "诚如"     "出来"
# [103] "出于"     "曾"       "趁"       "着"       "趁"       "处"
# [109] "在"       "乘"       "冲"       "等等"     "等到"     "等"
# [115] "第"       "当"       "着"       "当然"     "当地"     "当"
# [121] "多"       "多么"     "多少"     "对"       "对于"     "对待"
# [127] "对方"     "对比"     "得"       "得了"     "打"       "打"
# [133] "从"       "的"       "的确"     "的话"     "但"       "但凡"
# [139] "但是"     "大家"     "大"       "地"       "待"       "都"
# [145] "到"       "叮"       "咚"       "而言"     "而是"     "而已"
# [151] "而外"     "而后"     "而"       "况"       "而且"     "而"
# [157] "尔尔"     "尔"       "后"       "尔"       "二"       "来"
# [163] "非"       "独"       "非"       "特"       "非"       "徒"
# [169] "非但"     "否则"     "反过来"   "说"       "反过来"   "反而"
# [175] "反之"     "分别"     "凡是"     "凡"       "个"       "个别"
# [181] "固然"     "故"       "故此"     "故而"     "果然"     "果真"
# [187] "各"       "各个"     "各位"     "各种"     "各自"     "关于"
# [193] "具体"     "地"       "说"       "归"       "齐"       "归"
# [199] "根据"     "管"       "赶"       "跟"       "过"       "该"
# [205] "给"       "光"       "是"       "或者"     "或"       "曰"
# [211] "或是"     "或"       "则"       "或"       "何"       "何以"
# [217] "何况"     "何处"     "何时"     "还"       "要"       "还有"
# [223] "还是"     "还"       "后者"     "很"       "换"       "言"
# [229] "之"       "换句话说" "好"       "后"       "和"       "即"
# [805] "哈"       "哈哈"     "哉"       "哎"       "哎呀"     "哎哟"
# [811] "哗"       "哟"       "哦"       "哩"       "矣"       "哉"
# [817] "矣"       "乎"       "矣"       "焉"       "毋"       "宁"
# [823] "欤"       "嘿嘿"     "嘿"       "嘻"       "嘛"       "嘘"
# [829] "嘎"       "登"       "嘎"       "嗳"       "嗯"       "嗬"
# [835] "嗡嗡"     "嗡"       "喽"       "喔唷"     "喏"       "喂"
# [841] "啷"       "当"       "啪达"     "啦"       "啥"       "啐"
# [847] "啊"       "唉"       "哼"       "唷"       "哼"       "咧"
# [853] "咦"       "咚"       "咋"       "呼哧"     "呸"       "呵呵"
# [859] "呵"       "呢"       "呜"       "呼"       "呜"       "呗"
# [865] "呕"       "呃"       "呀"       "吱"       "吧"       "哒"
# [871] "吧"       "吗"       "吓"       "兮"       "儿"       "亦"
# [877] "了"       "乎"

# %%
# 1.4 What encoding do you have?

# You can check with this function in base R
validUTF8("This is a sentence")
# Out:
# [1] TRUE

# %%
# You can use the package utf8(), written by Patrick Perry from NYU
# Read about it here: https://github.com/patperry/r-utf8
# install.packages("utf8")
library("utf8")

# %%
as_utf8("\xF0\x9F\x98\x81")
print("\xF0\x9F\x98\x81") # There are issues with base R's print() function for Unicode
# any guesses what this is?
utf8_print("\xF0\x9F\x98\x81")
# Out:
# [1] "\U0001f601"
# [1] "\U0001f601"
# [1] "😁​"

# %%
# 1.5 What if you get a weird character and you're not sure?

# install.packages("stringi")
library("stringi")

# %%
# Use the encoding guesser to guess what this character is
stri_enc_detect("0x00E3")
# Out:
# [[1]]
# [[1]]$Encoding
# [1] "ISO-8859-1" "UTF-8"      "UTF-16BE"   "UTF-16LE"
#
# [[1]]$Language
# [1] "it" ""   ""   ""
#
# [[1]]$Confidence
# [1] 0.50 0.15 0.10 0.10

# %%
# 1.6 How do you convert encodings?

test_str <- "São Paulo"
validUTF8(test_str)

converted_str <- iconv("São Paulo", from = "UTF-8", to = "latin1")

converted_str
# Out:
# [1] TRUE
# [1] "São Paulo"

# %%
validUTF8(converted_str)
# Out:
# [1] FALSE

# %%
charToRaw(converted_str) # Latin-1 encoding

charToRaw(test_str) # UTF-8 encoding
# Out:
# [1] 53 e3 6f 20 50 61 75 6c 6f
#  [1] 53 c3 a3 6f 20 50 61 75 6c 6f

# %%
# But what about here?
iconv("São Paulo", from = "UTF-8", to = "ASCII")
# Out:
# [1] NA

# %% [markdown]
# # 2 Heap's Law

# %%
## 2 Demonstrate Heap's law

#     M = kT^b

# M = vocab size
# T = number of tokens
# k, b are constants

tokens <- tokens(data_corpus_inaugural, removePunct=TRUE) 
Tee <- lengths(tokens)
Tee <- sum(Tee)

inaug_dfm <- dfm(data_corpus_inaugural)

M <- nfeat(inaug_dfm)

# Let's check using parameter values from MRS for a corpus with more than 100,000 tokens

k <- 44
b <- .49

k * (Tee)^b
# Out:
# [1] 15084.15

# %%
## 3 Demonstrate Zipf's law

plot(log10(1:100), log10(topfeatures(inaug_dfm, 100)),
     xlab="log10(rank)", ylab="log10(frequency)", main="Top 100 Words")

# Fits a linear regression to check if slope is approx -1.0
regression <- lm(log10(topfeatures(inaug_dfm, 100)) ~ log10(1:100))

# Adds the fitted line from regression to the plot
abline(regression, col="red")
# Out:
# Plot with title “Top 100 Words”

# %%
# Returns the 95% confidence intervals for the regression coefficients
confint(regression)
# Out:
#              2.5 %     97.5 %
# (Intercept)   4.252963  4.3251105
# log10(1:100) -1.042916 -0.9986484

# %%
# Provides R-squared, F-test, and cofficient estimates from regression
summary(regression)
# Out:
# Call:
# lm(formula = log10(topfeatures(inaug_dfm, 100)) ~ log10(1:100))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.28549 -0.01420 -0.00635  0.01867  0.16100
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   4.28904    0.01818  235.94   <2e-16 ***
# log10(1:100) -1.02078    0.01115  -91.52   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.04473 on 98 degrees of freedom
# Multiple R-squared:  0.9884,	Adjusted R-squared:  0.9883
# F-statistic:  8376 on 1 and 98 DF,  p-value: < 2.2e-16

# %%
## 4 Stopwords: do they matter?

mydfm <- dfm(data_corpus_inaugural, remove=stopwords("english"))

plot(log10(1:100), log10(topfeatures(inaug_dfm, 100)),
     xlab="log10(rank)", ylab="log10(frequency)", main="Top 100 Words")

# Regression to check if slope is approx -1.0
regression <- lm(log10(topfeatures(inaug_dfm, 100)) ~ log10(1:100))
abline(regression, col="red")
confint(regression)
# Out:
#              2.5 %     97.5 %
# (Intercept)   4.252963  4.3251105
# log10(1:100) -1.042916 -0.9986484
# Plot with title “Top 100 Words”

# %%
## 5 Key Words In Context (KWIC) is a good way to summarize info about a topic

kwic(data_corpus_inaugural, "terror", 3)

#help(kwic)
# Out:
#   docname        from to   pre                       keyword
# 1 1797-Adams     1325 1325 violence , by             terror
# 2 1933-Roosevelt  112  112 unreasoning , unjustified terror
# 3 1941-Roosevelt  287  287 by a fatalistic           terror
# 4 1961-Kennedy    866  866 uncertain balance of      terror
# 5 1981-Reagan     813  813 Americans from the        terror
# 6 1997-Clinton   1055 1055 the fanaticism of         terror
# 7 1997-Clinton   1655 1655 strong defense against    terror
# 8 2009-Obama     1632 1632 aims by inducing          terror
#   post
# 1 , intrigue ,
# 2 which paralyzes needed
# 3 , we proved
# 4 that stays the
# 5 of runaway living
# 6 . And they
# 7 and destruction .
# 8 and slaughtering innocents

# %%
## 6 Measuring similarity

# This helps illustrate the value of the vector representation

# Cosine similarity--take the dot product of two vectors

# x * y = |x||y|cos
# cos = x*y/|x||y|

x <- c(1,2,3)
y <- c(1,2,3)
 
# Define the norm function

norm_vec <- function(x) sqrt(sum(x^2))

x %*% y / (norm_vec(x)*norm_vec(y))

# What if they're different

a <- c(1,2,3)
b <- c(1,2,4000)

a %*% b / (norm_vec(a)*norm_vec(b))
# Out:
#      [,1]
# [1,] 1
#      [,1]
# [1,] 0.8021177

# %%
# Let's do it with texts

last_speech_text <- data_corpus_inaugural[ndoc(data_corpus_inaugural)]
first_speech_text <- data_corpus_inaugural[1]

# %%
# Make a dfm of these two

first_last_dfm <- dfm(c(last_speech_text, first_speech_text), ignoredFeatures = stopwords("english"), stem = TRUE)
# Out:
# Warning message:
# “Argument ignoredFeatures not used.”Warning message:
# “Argument ignoredFeatures not used.”

# %% [raw]
# # Calculate similarity
#
# tmp <- similarity(first_last_dfm, margin = "documents")
#
# as.matrix(tmp)

# %%
# Calculate similarity

tmp <- textstat_simil(first_last_dfm, margin = "documents")

as.matrix(tmp)
# Out:
#                 2017-Trump 1789-Washington
# 2017-Trump      1.0000000  0.7279634
# 1789-Washington 0.7279634  1.0000000

# %%
# Let's see how stopwords/stemming affect this

first_last_dfm <- dfm(c(last_speech_text, first_speech_text))

# %%
# Calculate similarity

tmp <- textstat_simil(first_last_dfm, margin = "documents")

as.matrix(tmp)
# Out:
#                 2017-Trump 1789-Washington
# 2017-Trump      1.0000000  0.7324346
# 1789-Washington 0.7324346  1.0000000

# %%
# Make a dfm of a bunch

several_inaug_dfm <- dfm(corpus_subset(data_corpus_inaugural , Year > 1980), remove = stopwords("english"), stem = TRUE)

# %%
# Calculate similarity

tmp <- textstat_simil(several_inaug_dfm, margin = "documents")

as.matrix(tmp)
# Out:
#              1981-Reagan 1985-Reagan 1989-Bush 1993-Clinton 1997-Clinton
# 1981-Reagan  1.0000000   0.9704059   0.9603411 0.9443849    0.9366096
# 1985-Reagan  0.9704059   1.0000000   0.9557316 0.9485131    0.9480250
# 1989-Bush    0.9603411   0.9557316   1.0000000 0.9374917    0.9379579
# 1993-Clinton 0.9443849   0.9485131   0.9374917 1.0000000    0.9271750
# 1997-Clinton 0.9366096   0.9480250   0.9379579 0.9271750    1.0000000
# 2001-Bush    0.9494593   0.9416197   0.9545460 0.9308542    0.9307404
# 2005-Bush    0.9323529   0.9322253   0.9345042 0.9183421    0.9053546
# 2009-Obama   0.9423306   0.9441305   0.9475499 0.9096792    0.9421327
# 2013-Obama   0.9384555   0.9421446   0.9394478 0.9209066    0.9357481
# 2017-Trump   0.9348161   0.9335340   0.9431783 0.9194515    0.9268390
#              2001-Bush 2005-Bush 2009-Obama 2013-Obama 2017-Trump
# 1981-Reagan  0.9494593 0.9323529 0.9423306  0.9384555  0.9348161
# 1985-Reagan  0.9416197 0.9322253 0.9441305  0.9421446  0.9335340
# 1989-Bush    0.9545460 0.9345042 0.9475499  0.9394478  0.9431783
# 1993-Clinton 0.9308542 0.9183421 0.9096792  0.9209066  0.9194515
# 1997-Clinton 0.9307404 0.9053546 0.9421327  0.9357481  0.9268390
# 2001-Bush    1.0000000 0.9432043 0.9321777  0.9399379  0.9409308
# 2005-Bush    0.9432043 1.0000000 0.9044703  0.9228413  0.9267296
# 2009-Obama   0.9321777 0.9044703 1.0000000  0.9427078  0.9292572
# 2013-Obama   0.9399379 0.9228413 0.9427078  1.0000000  0.9252686
# 2017-Trump   0.9409308 0.9267296 0.9292572  0.9252686  1.0000000

# %%
# Specific comparisons

textstat_simil(several_inaug_dfm, "2009-Obama", margin = "documents")
# Out:
#              2009-Obama
# 2009-Obama    1.0000000
# 1981-Reagan   0.9423306
# 1985-Reagan   0.9441305
# 1989-Bush     0.9475499
# 1993-Clinton  0.9096792
# 1997-Clinton  0.9421327
# 2001-Bush     0.9321777
# 2005-Bush     0.9044703
# 2013-Obama    0.9427078
# 2017-Trump    0.9292572
